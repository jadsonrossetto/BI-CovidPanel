# %% [markdown]
# # Imports

# %%
import pandas as pd

# %% [markdown]
# # Importar csv para DataFrame

# %%
df = pd.read_csv("MICRODADOS.csv", encoding='latin-1', sep=";", low_memory=False)
# Out:
# <bound method NDFrame.head of         DataNotificacao DataCadastro DataDiagnostico DataColeta_RT_PCR  \
# 0            2023-03-26   2023-03-26      2023-03-26               NaN
# 1            2023-03-26   2023-03-26      2023-03-23               NaN
# 2            2023-03-26   2023-03-26      2023-03-22               NaN
# 3            2023-03-26   2023-03-26      2023-03-21               NaN
# 4            2023-03-26   2023-03-26      2023-03-23               NaN
# ...                 ...          ...             ...               ...
# 4753267      2020-02-27   2020-04-16      2020-02-09        2020-02-28
# 4753268      2020-02-27   2020-04-16      2020-02-16        2020-02-27
# 4753269      2020-02-27   2020-04-16      2020-02-15        2020-02-27
# 4753270      2020-02-25   2020-04-16      2020-02-13        2020-02-26
# 4753271      2020-01-23   2020-10-25      2020-01-20               NaN
#
#         DataColetaTesteRapido DataColetaSorologia DataColetaSorologiaIGG  \
# ...

# %% [markdown]
# # Mostrando os 5 primeiros do DataFrame

# %%
display(df.head)
# Out:
# <bound method NDFrame.head of         DataNotificacao DataCadastro DataDiagnostico DataColeta_RT_PCR  \
# 0            2023-03-26   2023-03-26      2023-03-26               NaN
# 1            2023-03-26   2023-03-26      2023-03-23               NaN
# 2            2023-03-26   2023-03-26      2023-03-22               NaN
# 3            2023-03-26   2023-03-26      2023-03-21               NaN
# 4            2023-03-26   2023-03-26      2023-03-23               NaN
# ...                 ...          ...             ...               ...
# 4753267      2020-02-27   2020-04-16      2020-02-09        2020-02-28
# 4753268      2020-02-27   2020-04-16      2020-02-16        2020-02-27
# 4753269      2020-02-27   2020-04-16      2020-02-15        2020-02-27
# 4753270      2020-02-25   2020-04-16      2020-02-13        2020-02-26
# 4753271      2020-01-23   2020-10-25      2020-01-20               NaN
#
#         DataColetaTesteRapido DataColetaSorologia DataColetaSorologiaIGG  \
# ...

# %% [markdown]
# # Criando a Query

# %%
query_df = df.query('Municipio == "CARIACICA" & ComorbidadeTabagismo == "Sim" & DataObito >= "2020" & Evolucao == "Óbito pelo COVID-19"')

# %% [markdown]
# # Mostrando a Query com os filtros

# %%
query_df[['Municipio', 'ComorbidadeTabagismo', 'DataObito', 'Evolucao']]
# Out:
#          Municipio ComorbidadeTabagismo   DataObito             Evolucao
# 118442   CARIACICA                  Sim  2023-01-10  Óbito pelo COVID-19
# 681672   CARIACICA                  Sim  2022-07-14  Óbito pelo COVID-19
# 810307   CARIACICA                  Sim  2022-01-23  Óbito pelo COVID-19
# 812692   CARIACICA                  Sim  2022-07-15  Óbito pelo COVID-19
# 961267   CARIACICA                  Sim  2022-06-29  Óbito pelo COVID-19
# ...            ...                  ...         ...                  ...
# 4728672  CARIACICA                  Sim  2020-06-19  Óbito pelo COVID-19
# 4729486  CARIACICA                  Sim  2020-05-08  Óbito pelo COVID-19
# 4734253  CARIACICA                  Sim  2020-05-10  Óbito pelo COVID-19
# 4734753  CARIACICA                  Sim  2020-05-05  Óbito pelo COVID-19
# 4744664  CARIACICA                  Sim  2020-04-21  Óbito pelo COVID-19
#
# [73 rows x 4 columns]
